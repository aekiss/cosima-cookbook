# %% [markdown]
# # ACCESS-OM2 0.1$^\circ$ Spinup
#
# This notebook analyses the model output from the November 2017 ACCESS-OM2 Pre-release, implemented at 0.1°.

# %% [markdown]
# ## Current Status
#
#
# |** Run Name** | **Forcing** | ** Run ** | ** Status **|
# |--------------|---------|-------------------------------------------------|-------------|
# |01deg_jra55v13_ryf9091_spinup1 | JRA55 V1.3 RYF9091; stripy wind| | 1 month so far, dt=120s|
#
# ### Notes
#
# **Last updated 22 November 2017**

# %%
# %matplotlib inline

import cosima_cookbook as cc
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np
# Out:
# netcdf_index loaded.

# %%
cc.build_index()
# Out:
# Found 7003 new variables
# Saving results in database...
# Indexing complete.
# True

# %% [markdown]
# ## Experiments

# %%
# This subset of cases are the important ones
esub = [
 '01deg_jra55v13_ryf9091_spinup1'
       ]

# %% [markdown]
# ## Wind Stress
# Just a simple plot showing zonally averaged zonal wind stress from each case.

# %%
cc.plots.wind_stress(esub)
# Out:
# HBox(children=(IntProgress(value=0, description='experiments', max=1), HTML(value='')))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-eb70fafe4b70> in <module>()
# ----> 1 cc.plots.wind_stress(esub)
#
# ~/github/OceansAus/cosima-cookbook/cosima_cookbook/plots/lineplots.py in wind_stress(expts)
#      20     results = []
#      21     for expt in tqdm_notebook(expts, leave=False, desc='experiments'):
# ---> 22         result = {'mean_tau_x': cc.diagnostics.mean_tau_x(expt),
#      23                   'expt': expt }
#      24         results.append(result)
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     560
#     561     def __call__(self, *args, **kwargs):
# --> 562         return self._cached_call(args, kwargs)[0]
#     563
#     564     def __reduce__(self):
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/joblib/memory.py in _cached_call(self, args, kwargs)
#     508                           'directory %s'
#     509                         % (name, argument_hash, output_dir))
# --> 510             out, metadata = self.call(*args, **kwargs)
#     511             if self.mmap_mode is not None:
#     512                 # Memmap the output at the first call to be consistent with
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/joblib/memory.py in call(self, *args, **kwargs)
#     742         if self._verbose > 0:
#     743             print(format_call(self.func, args, kwargs))
# --> 744         output = self.func(*args, **kwargs)
#     745         self._persist_output(output, output_dir)
#     746         duration = time.time() - start_time
#
# ~/github/OceansAus/cosima-cookbook/cosima_cookbook/diagnostics/mean_tau_x.py in mean_tau_x(expt)
#      11                             'tau_x',
#      12                             time_units = 'days since 1900-01-01',
# ---> 13                             n=10)
#      14
#      15     mean_tau_x = tau_x.mean('xu_ocean').mean('time')
#
# ~/github/OceansAus/cosima-cookbook/cosima_cookbook/netcdf_index.py in get_nc_variable(expt, ncfile, variable, chunks, n, op, time_units, use_bag)
#     308
#     309     if len(ncfiles) == 0:
# --> 310         raise ValueError("No variable {} found for {} in {}".format(variable, expt, ncfile))
#     311
#     312     #print('Found {} ncfiles'.format(len(ncfiles)))
#
# ValueError: No variable tau_x found for 01deg_jra55v13_ryf9091_spinup1 in ocean_month.nc

# %% [markdown]
# ## Ocean Scalars
# The following series of plots shows global timeseries of key metrics.

# %%
variables = ['ke_tot',
             'temp_global_ave', 
             'salt_global_ave',
             'salt_surface_ave',
             'total_ocean_sfc_salt_flux_coupler',
             'eta_global']

# %%
cc.plots.annual_scalar(esub, variables)

# %% [markdown]
# # Transports

# %%
cc.plots.drake_passage(esub)
# Out:
# HBox(children=(IntProgress(value=0, description='experiments', max=1), HTML(value='')))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-c7a7e0655452> in <module>()
# ----> 1 cc.plots.drake_passage(esub)
#
# ~/github/OceansAus/cosima-cookbook/cosima_cookbook/plots/lineplots.py in drake_passage(expts)
#     107     results = []
#     108     for expt in tqdm_notebook(expts, leave=False, desc='experiments'):
# --> 109         transport = cc.diagnostics.drake_passage(expt)
#     110
#     111         result = {'transport': transport,
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     560
#     561     def __call__(self, *args, **kwargs):
# --> 562         return self._cached_call(args, kwargs)[0]
#     563
#     564     def __reduce__(self):
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/joblib/memory.py in _cached_call(self, args, kwargs)
#     508                           'directory %s'
#     509                         % (name, argument_hash, output_dir))
# --> 510             out, metadata = self.call(*args, **kwargs)
#     511             if self.mmap_mode is not None:
#     512                 # Memmap the output at the first call to be consistent with
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/joblib/memory.py in call(self, *args, **kwargs)
#     742         if self._verbose > 0:
#     743             print(format_call(self.func, args, kwargs))
# --> 744         output = self.func(*args, **kwargs)
#     745         self._persist_output(output, output_dir)
#     746         duration = time.time() - start_time
#
# ~/github/OceansAus/cosima-cookbook/cosima_cookbook/diagnostics/simple.py in drake_passage(expt)
#      39                          chunks={'yt_ocean':200},
#      40                          time_units = 'days since 1700-01-01',
# ---> 41                          use_bag=False)
#      42
#      43     tx_trans = tx.sel(xu_ocean=-69,method='nearest').sel(yt_ocean=slice(-72,-52))
#
# ~/github/OceansAus/cosima-cookbook/cosima_cookbook/netcdf_index.py in get_nc_variable(expt, ncfile, variable, chunks, n, op, time_units, use_bag)
#     308
#     309     if len(ncfiles) == 0:
# --> 310         raise ValueError("No variable {} found for {} in {}".format(variable, expt, ncfile))
#     311
#     312     #print('Found {} ncfiles'.format(len(ncfiles)))
#
# ValueError: No variable tx_trans_int_z found for 01deg_jra55v13_ryf9091_spinup1 in ocean_month.nc

# %%
cc.plots.bering_strait(esub)

# %% [markdown]
# # Meridional Overturning Circulation

# %%
cc.plots.psi_avg(esub, 10, GM=True)

# %%
cc.plots.aabw(esub, GM=True)

# %%
cc.plots.amoc(esub, GM=True)

# %%
cc.plots.amoc_south(esub, GM=True)

# %% [markdown]
# # Sea Surface Temperature
# LH column shows SST, RH column shows difference from Year 1.

# %%
cc.plots.sea_surface_temperature(esub)
# Out:
# HBox(children=(IntProgress(value=0, description='experiments', max=1), HTML(value='')))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-0730b3a65e7e> in <module>()
# ----> 1 cc.plots.sea_surface_temperature(esub)
#
# ~/github/OceansAus/cosima-cookbook/cosima_cookbook/plots/maps.py in sea_surface_temperature(expts)
#      16     results = []
#      17     for expt in tqdm_notebook(expts, leave=False, desc='experiments'):
# ---> 18         SST, SSTdiff = cc.diagnostics.sea_surface_temperature(expt)
#      19
#      20         result = {'SST': SST,
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     560
#     561     def __call__(self, *args, **kwargs):
# --> 562         return self._cached_call(args, kwargs)[0]
#     563
#     564     def __reduce__(self):
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/joblib/memory.py in _cached_call(self, args, kwargs)
#     508                           'directory %s'
#     509                         % (name, argument_hash, output_dir))
# --> 510             out, metadata = self.call(*args, **kwargs)
#     511             if self.mmap_mode is not None:
#     512                 # Memmap the output at the first call to be consistent with
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/joblib/memory.py in call(self, *args, **kwargs)
#     742         if self._verbose > 0:
#     743             print(format_call(self.func, args, kwargs))
# --> 744         output = self.func(*args, **kwargs)
#     745         self._persist_output(output, output_dir)
#     746         duration = time.time() - start_time
#
# ~/github/OceansAus/cosima-cookbook/cosima_cookbook/diagnostics/simple.py in sea_surface_temperature(expt)
#      73 def sea_surface_temperature(expt):
#      74     ## Load SST from expt - last 10 outputs (TODO: would prefer to do this by year)
# ---> 75     SST = get_nc_variable(expt, 'ocean_month.nc', 'surface_temp',n=10, time_units = 'days since 1900-01-01')
#      76     #SSS = get_nc_variable(expt, 'ocean.nc', 'temp',n=10,time_units = 'days since 1900-01-01').isel(st_ocean=0)
#      77
#
# ~/github/OceansAus/cosima-cookbook/cosima_cookbook/netcdf_index.py in get_nc_variable(expt, ncfile, variable, chunks, n, op, time_units, use_bag)
#     308
#     309     if len(ncfiles) == 0:
# --> 310         raise ValueError("No variable {} found for {} in {}".format(variable, expt, ncfile))
#     311
#     312     #print('Found {} ncfiles'.format(len(ncfiles)))
#
# ValueError: No variable surface_temp found for 01deg_jra55v13_ryf9091_spinup1 in ocean_month.nc

# %%
cc.plots.sea_surface_salinity(esub[:3])
# Out:
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/dask/array/numpy_compat.py:45: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %% [markdown]
# # Zonal Mean transects

# %%
cc.plots.zonal_mean(esub,'temp')
# Out:
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/dask/array/numpy_compat.py:45: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
cc.plots.zonal_mean(esub,'salt')
# Out:
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/dask/array/numpy_compat.py:45: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
