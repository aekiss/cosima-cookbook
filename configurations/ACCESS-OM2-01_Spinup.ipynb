# %% [markdown]
# # ACCESS-OM2 0.1$^\circ$ Spinup
#
# This notebook analyses the model output from the November 2017 ACCESS-OM2 Pre-release, implemented at 0.1°.

# %% [markdown]
# ## Current Status
#
#
# |** Run Name** | **Forcing** | ** Run ** | ** Status **|
# |--------------|---------|-------------------------------------------------|-------------|
# |01deg_jra55v13_ryf9091_spinup1 | JRA55 V1.3 RYF9091; stripy wind| | 1 month so far, dt=120s|
#
# ### Notes
#
# **Last updated 22 November 2017**

# %%
# %matplotlib inline

import cosima_cookbook as cc
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np
# Out:
# netcdf_index loaded.

# %%
cc.build_index()
# Out:
# Found 100890 new variables
# Saving results in database...
# Indexing complete.
# True

# %% [markdown]
# ## Experiments

# %%
# This subset of cases are the important ones
esub = [
 '01deg_jra55v13_ryf8485_spinup6'
       ]

# %% [markdown]
# ## Wind Stress
# Just a simple plot showing zonally averaged zonal wind stress from each case.

# %%
cc.plots.wind_stress(esub)

# %% [markdown]
# ## Ocean Scalars
# The following series of plots shows global timeseries of key metrics.

# %%
variables = ['ke_tot',
             'temp_global_ave', 
             'salt_global_ave',
             'salt_surface_ave',
             'total_ocean_sfc_salt_flux_coupler',
             'eta_global']

# %%
cc.plots.annual_scalar(esub, variables)

# %% [markdown]
# # Transports

# %%
cc.plots.drake_passage(esub)

# %%
cc.plots.bering_strait(esub)

# %% [markdown]
# # Meridional Overturning Circulation

# %%
cc.plots.psi_avg(esub, 10)

# %%
cc.plots.aabw(esub)

# %%
cc.plots.amoc(esub)

# %%
cc.plots.amoc_south(esub)

# %% [markdown]
# # Sea Surface Temperature
# LH column shows SST, RH column shows difference from Year 1.

# %%
cc.plots.sea_surface_temperature(esub, resolution=0.1)
# Out:
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/dask/array/numpy_compat.py:45: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
cc.plots.sea_surface_salinity(esub)
# Out:
# HBox(children=(IntProgress(value=0, description='experiments', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='get_nc_variable:', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='get_nc_variable:', max=12), HTML(value='')))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-943899ecef30> in <module>()
# ----> 1 cc.plots.sea_surface_salinity(esub)
#
# ~/github/OceansAus/cosima-cookbook/cosima_cookbook/plots/maps.py in sea_surface_salinity(expts, resolution)
#      51     results = []
#      52     for expt in tqdm_notebook(expts, leave=False, desc='experiments'):
# ---> 53         SSS, SSSdiff = cc.diagnostics.sea_surface_salinity(expt, resolution)
#      54
#      55         result = {'SSS': SSS,
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     560
#     561     def __call__(self, *args, **kwargs):
# --> 562         return self._cached_call(args, kwargs)[0]
#     563
#     564     def __reduce__(self):
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/joblib/memory.py in _cached_call(self, args, kwargs)
#     508                           'directory %s'
#     509                         % (name, argument_hash, output_dir))
# --> 510             out, metadata = self.call(*args, **kwargs)
#     511             if self.mmap_mode is not None:
#     512                 # Memmap the output at the first call to be consistent with
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/joblib/memory.py in call(self, *args, **kwargs)
#     742         if self._verbose > 0:
#     743             print(format_call(self.func, args, kwargs))
# --> 744         output = self.func(*args, **kwargs)
#     745         self._persist_output(output, output_dir)
#     746         duration = time.time() - start_time
#
# ~/github/OceansAus/cosima-cookbook/cosima_cookbook/diagnostics/simple.py in sea_surface_salinity(expt, resolution)
#     120     # Average over last 10 time slices - prefer to do this by year.
#     121     SSS = SSS.mean('time')
# --> 122     SSSdiff = SSS - SSS_WOA13.mean('time').values
#     123
#     124     return SSS, SSSdiff
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/xarray/core/dataarray.py in func(self, other)
#    1631
#    1632             variable = (f(self.variable, other_variable)
# -> 1633                         if not reflexive
#    1634                         else f(other_variable, self.variable))
#    1635             coords = self.coords._merge_raw(other_coords)
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/xarray/core/variable.py in func(self, other)
#    1403             with np.errstate(all='ignore'):
#    1404                 new_data = (f(self_data, other_data)
# -> 1405                             if not reflexive
#    1406                             else f(other_data, self_data))
#    1407             result = Variable(dims, new_data)
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/dask/array/core.py in __sub__(self, other)
#    1417
#    1418     def __sub__(self, other):
# -> 1419         return elemwise(operator.sub, self, other)
#    1420
#    1421     def __rsub__(self, other):
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/dask/array/core.py in elemwise(op, *args, **kwargs)
#    2483     shapes = [getattr(arg, 'shape', ()) for arg in args]
#    2484     shapes = [s if isinstance(s, Iterable) else () for s in shapes]
# -> 2485     out_ndim = len(broadcast_shapes(*shapes))   # Raises ValueError if dimensions mismatch
#    2486     expr_inds = tuple(range(out_ndim))[::-1]
#    2487
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/dask/array/core.py in broadcast_shapes(*shapes)
#    2455         if any(i != -1 and i != 1 and i != dim and not np.isnan(i) for i in sizes):
#    2456             raise ValueError("operands could not be broadcast together with "
# -> 2457                              "shapes {0}".format(' '.join(map(str, shapes))))
#    2458         out.append(dim)
#    2459     return tuple(reversed(out))
#
# ValueError: operands could not be broadcast together with shapes (2700, 3600) (300, 360)

# %% [markdown]
# # Zonal Mean transects

# %%
cc.plots.zonal_mean(esub,'temp')

# %%
cc.plots.zonal_mean(esub,'salt')

# %% [markdown]
# # Ice area timeseries

# %% [markdown]
# # Ice volume timeseries

# %% [markdown]
# # Ice limit maps: one per month, with contours for each year

# %% [markdown]
# todo: get lat/lon data thats useable for pcolormesh
# - check the grid the same as for mom
# - if so, use that

# %% [markdown]
# # Convergence checks: divergence, stress, etc
