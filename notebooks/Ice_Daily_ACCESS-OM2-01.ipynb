# %% [markdown]
# # Sea Ice Daily Figures for ACCESS-OM2_01

# %% [markdown]
# Author: Andrew Kiss; heavily based on Adele Morrison's "Ice Validation mom025"

# %%
# %matplotlib inline

from glob import glob
import os,sys
import matplotlib.pyplot as plt
import numpy as np
import netCDF4 as nc
from tqdm import tqdm_notebook
from mpl_toolkits.basemap import Basemap
from calendar import month_abbr
from netCDF4 import Dataset
import cmocean as cm
import string
# Out:
# /home/156/aek156/.local/lib/python3.6/site-packages/cmocean/tools.py:76: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not mpl.cbook.is_string_like(rgbin[0]):

# %%
# figdir = 'figures/access-om2-01/Ice_Daily_ACCESS-OM2-01/'
figdir = '/g/data/v45/aek156/figures/access-om2-01/Ice_Daily_ACCESS-OM2-01/'
if not os.path.exists(figdir):
    os.makedirs (figdir)

def savefigure(fname):
    plt.savefig(os.path.join(figdir, fname),dpi=100, bbox_inches="tight")  # comment out to disable saving
    return

# %%
# model data paths:
model = 'access-om2-01'
expt = '01deg_jra55v13_ryf8485_spinup6'
DataDir = os.path.join('/g/data3/hh5/tmp/cosima/', model)
expdir = os.path.join(DataDir, expt)
# date = '0004-07-05' # nicest view
# date = '0004-07-12'
# fn01 = '/g/data3/hh5/tmp/cosima/' + model + '/' +  expt + '/output023/ice/OUTPUT/iceh.' + date + '.nc'

# sea ice observation data paths:
obsVersion = 3
if obsVersion==3:
    ObsDir = '/g/data1a/v45/aek156/data/NOAA/G02202_V3'  # from http://nsidc.org/data/G02202
    ObsDirExt = '/g/data1a/v45/aek156/data/NOAA/G02135'  # from http://nsidc.org/data/g02135
else:
# v2
    ObsDir = '/g/data/v45/akm157/data/NSIDC/NOAA_G02202_v2_conc_monthly/'
    ObsDirExt = '/g/data/v45/akm157/data/NSIDC/NOAA_G02135_extent_monthly/' # v2.1

# # length of climatology (may be corrected below):
# n_years = 10

# # path to model sea ice data:
# dataFileList = glob(os.path.join(expdir, 'output*/ice/OUTPUT/iceh.????-??.nc'))  # monthly
# dataFileList.sort()
# dataFileListDaily = glob(os.path.join(expdir, 'output*/ice/OUTPUT/iceh.????-??-??.nc'))  # daily
# dataFileListDaily.sort()

# # update n_years to avoid exceeding available data
# if model=='mom025':
#     filesPerYear = 1
# elif model=='mom01v5':
#     filesPerYear = 4
# elif model=='access-om2-01':
#     filesPerYear = 12
# total_years = len(dataFileList)/filesPerYear  # NB: typically not an integer
# n_years = min(n_years, int(total_years) )
# n_files = n_years*filesPerYear
# firstfile = int(total_years-n_years)*filesPerYear  # start of calendar year

# paths to obs data:
if obsVersion==3:
    obsNHFileList = glob(os.path.join(ObsDir, 'north/monthly/*.nc'))
    obsSHFileList = glob(os.path.join(ObsDir, 'south/monthly/*.nc'))
    obsExtNHFileList = glob(os.path.join(ObsDirExt, 'north/monthly/data/*.csv'))
    obsExtSHFileList = glob(os.path.join(ObsDirExt, 'south/monthly/data/*.csv'))
else:
    obsNHFileList = glob(os.path.join(ObsDir, 'nh/*.nc'))
    obsSHFileList = glob(os.path.join(ObsDir, 'sh/*.nc'))
    obsExtNHFileList = glob(os.path.join(ObsDirExt, 'nh/*.csv'))
    obsExtSHFileList = glob(os.path.join(ObsDirExt, 'sh/*.csv'))

obsNHFileList.sort()
obsSHFileList.sort()
obsExtNHFileList.sort()
obsExtSHFileList.sort()


# get model grid data:
gridFileList = glob(os.path.join(expdir, 'output*/ocean/ocean_grid.nc'))
gridFileList.sort()
ncFile = nc.Dataset(gridFileList[0], mode='r')
xt_ocean = ncFile.variables['xt_ocean'][...]
yt_ocean = ncFile.variables['yt_ocean'][...]
lon_t = ncFile.variables['geolon_t'][...]
lat_t = ncFile.variables['geolat_t'][...]
area_t = ncFile.variables['area_t'][...]
# NLAT_half = int(np.shape(area_t)[0]/2)
ht = ncFile.variables['ht'][...]
land_mask = np.copy(ht)
land_mask[np.where(ht>30)] = 0
land_mask[np.where(ht<=30)] = 1

# %%
############################################
####### obs climatology:
# for obs just use years 1988-1997, because concentration not available before then and 
# climate change after then

# NH All:
# CN_obs_NH = [[] for _ in range(12)]  # list keeps months separate
CN_obs_NH = [None]*12
for mo in tqdm_notebook(range(12), leave=False, desc='month'):
    # length of climatology:
    obs_list = [IceFile for IceFile in obsNHFileList if (IceFile.find(str(mo+1).zfill(2)+'_v0')>0 and 
        IceFile.find('nh_f')>0 and float(IceFile[-16:-12])>1987 and \
        float(IceFile[-16:-12])<1998)] 
    n_yrs = len(obs_list)
    for IceFile in tqdm_notebook(obs_list, leave=False, desc='year'):
    #     print('opening '+IceFile)
        ncFile = nc.Dataset(IceFile, mode='r')
        tmp = ncFile.variables['seaice_conc_monthly_cdr'][0,...]
#         if len(CN_obs_NH[mo])==0:
        if CN_obs_NH[mo]==None:
            CN_obs_NH[mo] = tmp
        else:
            CN_obs_NH[mo] = CN_obs_NH[mo] + tmp
    # divide by n_yrs and mask land / arctic pole hole:
    CN_obs_NH[mo] = np.ma.masked_where(CN_obs_NH[mo]<0,CN_obs_NH[mo]) / n_yrs
    CN_obs_NH[mo] = np.ma.masked_where(CN_obs_NH[mo]>2,CN_obs_NH[mo])
obs_lat_NH = ncFile.variables['latitude'][...]
obs_lon_NH = ncFile.variables['longitude'][...]
# Out:
# HBox(children=(IntProgress(value=0, description='month', max=12), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/numpy/ma/core.py:3902: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   check = self.filled(0).__eq__(other)
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))

# %%
# SH All:
CN_obs_SH = [None]*12
for mo in tqdm_notebook(range(12), leave=False, desc='month'):
    # length of climatology:
    obs_list = [IceFile for IceFile in obsSHFileList if (IceFile.find(str(mo+1).zfill(2)+'_v0')>0 and 
        IceFile.find('sh_f')>0 and float(IceFile[-16:-12])>1987 and \
        float(IceFile[-16:-12])<1998)] 
    n_yrs = len(obs_list)
    for IceFile in tqdm_notebook(obs_list, leave=False, desc='year'):
    #     print('opening '+IceFile)
        ncFile = nc.Dataset(IceFile, mode='r')
        tmp = ncFile.variables['seaice_conc_monthly_cdr'][0,...]
        if CN_obs_SH[mo]==None:
            CN_obs_SH[mo] = tmp
        else:
            CN_obs_SH[mo] = CN_obs_SH[mo] + tmp
    # divide by n_yrs and mask land / arctic pole hole:
    CN_obs_SH[mo] = np.ma.masked_where(CN_obs_SH[mo]<0,CN_obs_SH[mo]) / n_yrs
    CN_obs_SH[mo] = np.ma.masked_where(CN_obs_SH[mo]>2,CN_obs_SH[mo])
obs_lat_SH = ncFile.variables['latitude'][...]
obs_lon_SH = ncFile.variables['longitude'][...]
# Out:
# HBox(children=(IntProgress(value=0, description='month', max=12), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/numpy/ma/core.py:3902: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   check = self.filled(0).__eq__(other)
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='year', max=10), HTML(value='')))

# %%
icehFileList = glob(os.path.join(expdir, 'output*/ice/OUTPUT/iceh.0013-*-*.nc'))
icehFileList.sort()

varnames = ['hi', 'aice']
views = ['Arctic_closeup', 'Arctic', 'Antarctic']

for varname in tqdm_notebook(varnames[0:1], leave=False, desc='variables'):
    for view in tqdm_notebook(views, leave=False, desc='views'):
        for fpath in tqdm_notebook(icehFileList, leave=False, desc='day'):
            fname=os.path.basename(fpath)
            date = fname.split('.')[1]
            month = int(date.split('-')[1])
            outname = view + '_' + varname + '_' + date + '.png'

            if os.path.exists(os.path.join(figdir, outname)):
                print('Skipping ' + outname + ' (file exists)')
            else:
                nc = Dataset(fpath, mode='r')
                var = nc.variables[varname][:][0,:,:]
                nc.close()

                if varname == 'aice':
                    desc = 'Ice concentration'
                    levels = np.arange(0,1.01,.01)
                    ticks = [0,.2,.4,.6,.8,1]
                    ext = 'neither'
                elif varname == 'hi':
                    desc = 'Ice thickness (m)'
                    levels = np.arange(0,6.01,.06)
                    ticks = range(7)
                    ext = 'max'
                else:
                    desc = '***UNKNOWN***'
                    levels = np.arange(0,1.01,.1)
                    ticks = [0,.2,.4,.6,.8,1]
                    ext = 'neither'

                font = {'size':24}
                tick_font=24

                fig = plt.figure(figsize=(30,30))
                if view == 'Arctic':
                    m = Basemap(projection ='npstere',boundinglat=45,lon_0=-10,resolution='l')
                elif view == 'Arctic_closeup':
                    m = Basemap(projection ='npstere',boundinglat=70,lon_0=-10,resolution='l')
                else:
                    m = Basemap(projection ='spstere',boundinglat=-50,lon_0=170,resolution='l')

                # m = Basemap(projection ='ortho',resolution='l',lat_0=90,lon_0=45,
                #            llcrnrx=-m.urcrnrx/2.,llcrnry=-m.urcrnry/2.,urcrnrx=m.urcrnrx/2.,urcrnry=m.urcrnry/2.)
                # #             llcrnrlat=60,urcrnrlat=60,
                # #             llcrnrlon=-45,urcrnrlon=45)
                # #             llcrnrlon=loncorners[0],urcrnrlon=loncorners[2]) ,boundinglat=48
                x,y = m(*(lon_t,lat_t))
                ctr = m.contourf(x,y,var,levels=levels,cmap=cm.cm.ice, extend=ext) #, vmin=0, vmax=1.1)
                ctr.cmap.set_over(color='w', alpha=None)
                if view.startswith('Arctic'):
                    xobs,yobs = m(*(obs_lon_NH,obs_lat_NH))
                    m.contour(xobs,yobs,CN_obs_NH[month-1],[0.3],colors='r')
                else:
                    xobs,yobs = m(*(obs_lon_SH,obs_lat_SH))
                    m.contour(xobs,yobs,CN_obs_SH[month-1],[0.3],colors='r')

                plt.title(desc + ', ' + date,font)
                cbar = m.colorbar(ctr, location = 'bottom', pad = "6%")
                cbar.set_label(desc,size=tick_font)
                cbar.set_ticks(ticks)
                cbar_labels=plt.getp(cbar.ax.axes,'xticklabels')
                plt.setp(cbar_labels,fontsize=tick_font)
                m.drawmapboundary(fill_color='gray') # background color - for non-ocean areas
                # fill continents, set lake color same as ocean color.
                # m.fillcontinents(color='gray',lake_color='gray')
                # draw parallels and meridians.
                # label parallels on right and top
                # meridians on bottom and left
                parallels = np.arange(-80.,81,10.)
                # labels = [left,right,top,bottom]
                m.drawparallels(parallels,color='white')#,labels=[False,True,True,False],size=tick_font)
                meridians = np.arange(0.,351.,20.)
                m.drawmeridians(meridians,labels=[True,False,False,True],size=tick_font,color='white')
                savefigure(outname)
                plt.close()
# Out:
# HBox(children=(IntProgress(value=0, description='variables', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='views', max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='day', max=365), HTML(value='')))
# Skipping Arctic_closeup_hi_0013-01-01.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-02.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-03.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-04.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-05.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-06.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-07.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-08.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-09.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-10.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-11.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-12.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-13.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-14.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-15.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-16.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-17.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-18.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-19.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-20.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-21.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-22.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-23.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-24.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-25.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-26.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-27.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-28.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-29.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-30.png (file exists)
# Skipping Arctic_closeup_hi_0013-01-31.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-01.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-02.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-03.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-04.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-05.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-06.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-07.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-08.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-09.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-10.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-11.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-12.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-13.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-14.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-15.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-16.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-17.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-18.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-19.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-20.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-21.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-22.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-23.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-24.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-25.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-26.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-27.png (file exists)
# Skipping Arctic_closeup_hi_0013-02-28.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-01.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-02.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-03.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-04.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-05.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-06.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-07.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-08.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-09.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-10.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-11.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-12.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-13.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-14.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-15.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-16.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-17.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-18.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-19.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-20.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-21.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-22.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-23.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-24.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-25.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-26.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-27.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-28.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-29.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-30.png (file exists)
# Skipping Arctic_closeup_hi_0013-03-31.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-01.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-02.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-03.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-04.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-05.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-06.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-07.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-08.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-09.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-10.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-11.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-12.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-13.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-14.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-15.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-16.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-17.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-18.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-19.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-20.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-21.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-22.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-23.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-24.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-25.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-26.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-27.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-28.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-29.png (file exists)
# Skipping Arctic_closeup_hi_0013-04-30.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-01.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-02.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-03.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-04.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-05.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-06.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-07.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-08.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-09.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-10.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-11.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-12.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-13.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-14.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-15.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-16.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-17.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-18.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-19.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-20.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-21.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-22.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-23.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-24.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-25.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-26.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-27.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-28.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-29.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-30.png (file exists)
# Skipping Arctic_closeup_hi_0013-05-31.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-01.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-02.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-03.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-04.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-05.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-06.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-07.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-08.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-09.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-10.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-11.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-12.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-13.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-14.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-15.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-16.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-17.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-18.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-19.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-20.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-21.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-22.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-23.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-24.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-25.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-26.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-27.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-28.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-29.png (file exists)
# Skipping Arctic_closeup_hi_0013-06-30.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-01.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-02.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-03.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-04.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-05.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-06.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-07.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-08.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-09.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-10.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-11.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-12.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-13.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-14.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-15.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-16.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-17.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-18.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-19.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-20.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-21.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-22.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-23.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-24.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-25.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-26.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-27.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-28.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-29.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-30.png (file exists)
# Skipping Arctic_closeup_hi_0013-07-31.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-01.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-02.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-03.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-04.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-05.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-06.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-07.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-08.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-09.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-10.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-11.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-12.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-13.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-14.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-15.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-16.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-17.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-18.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-19.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-20.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-21.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-22.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-23.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-24.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-25.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-26.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-27.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-28.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-29.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-30.png (file exists)
# Skipping Arctic_closeup_hi_0013-08-31.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-01.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-02.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-03.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-04.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-05.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-06.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-07.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-08.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-09.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-10.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-11.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-12.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-13.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-14.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-15.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-16.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-17.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-18.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-19.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-20.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-21.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-22.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-23.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-24.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-25.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-26.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-27.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-28.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-29.png (file exists)
# Skipping Arctic_closeup_hi_0013-09-30.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-01.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-02.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-03.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-04.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-05.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-06.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-07.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-08.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-09.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-10.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-11.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-12.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-13.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-14.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-15.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-16.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-17.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-18.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-19.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-20.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-21.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-22.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-23.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-24.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-25.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-26.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-27.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-28.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-29.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-30.png (file exists)
# Skipping Arctic_closeup_hi_0013-10-31.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-01.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-02.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-03.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-04.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-05.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-06.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-07.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-08.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-09.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-10.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-11.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-12.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-13.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-14.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-15.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-16.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-17.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-18.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-19.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-20.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-21.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-22.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-23.png (file exists)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1708: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   limb = ax.axesPatch
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1711: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   if limb is not ax.axesPatch:
# Skipping Arctic_closeup_hi_0013-11-25.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-26.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-27.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-28.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-29.png (file exists)
# Skipping Arctic_closeup_hi_0013-11-30.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-01.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-02.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-03.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-04.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-05.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-06.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-07.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-08.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-09.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-10.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-11.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-12.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-13.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-14.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-15.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-16.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-17.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-18.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-19.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-20.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-21.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-22.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-23.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-24.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-25.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-26.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-27.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-28.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-29.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-30.png (file exists)
# Skipping Arctic_closeup_hi_0013-12-31.png (file exists)
# HBox(children=(IntProgress(value=0, description='day', max=365), HTML(value='')))
# Skipping Arctic_hi_0013-01-01.png (file exists)
# Skipping Arctic_hi_0013-01-02.png (file exists)
# Skipping Arctic_hi_0013-01-03.png (file exists)
# Skipping Arctic_hi_0013-01-04.png (file exists)
# Skipping Arctic_hi_0013-01-05.png (file exists)
# Skipping Arctic_hi_0013-01-06.png (file exists)
# Skipping Arctic_hi_0013-01-07.png (file exists)
# Skipping Arctic_hi_0013-01-08.png (file exists)
# Skipping Arctic_hi_0013-01-09.png (file exists)
# Skipping Arctic_hi_0013-01-10.png (file exists)
# Skipping Arctic_hi_0013-01-11.png (file exists)
# Skipping Arctic_hi_0013-01-12.png (file exists)
# Skipping Arctic_hi_0013-01-13.png (file exists)
# Skipping Arctic_hi_0013-01-14.png (file exists)
# Skipping Arctic_hi_0013-01-15.png (file exists)
# Skipping Arctic_hi_0013-01-16.png (file exists)
# Skipping Arctic_hi_0013-01-17.png (file exists)
# Skipping Arctic_hi_0013-01-18.png (file exists)
# Skipping Arctic_hi_0013-01-19.png (file exists)
# Skipping Arctic_hi_0013-01-20.png (file exists)
# Skipping Arctic_hi_0013-01-21.png (file exists)
# Skipping Arctic_hi_0013-01-22.png (file exists)
# Skipping Arctic_hi_0013-01-23.png (file exists)
# Skipping Arctic_hi_0013-01-24.png (file exists)
# Skipping Arctic_hi_0013-01-25.png (file exists)
# Skipping Arctic_hi_0013-01-26.png (file exists)
# Skipping Arctic_hi_0013-01-27.png (file exists)
# Skipping Arctic_hi_0013-01-28.png (file exists)
# Skipping Arctic_hi_0013-01-29.png (file exists)
# Skipping Arctic_hi_0013-01-30.png (file exists)
# Skipping Arctic_hi_0013-01-31.png (file exists)
# Skipping Arctic_hi_0013-02-01.png (file exists)
# Skipping Arctic_hi_0013-02-02.png (file exists)
# Skipping Arctic_hi_0013-02-03.png (file exists)
# Skipping Arctic_hi_0013-02-04.png (file exists)
# Skipping Arctic_hi_0013-02-05.png (file exists)
# Skipping Arctic_hi_0013-02-06.png (file exists)
# Skipping Arctic_hi_0013-02-07.png (file exists)
# Skipping Arctic_hi_0013-02-08.png (file exists)
# Skipping Arctic_hi_0013-02-09.png (file exists)
# Skipping Arctic_hi_0013-02-10.png (file exists)
# Skipping Arctic_hi_0013-02-11.png (file exists)
# Skipping Arctic_hi_0013-02-12.png (file exists)
# Skipping Arctic_hi_0013-02-13.png (file exists)
# Skipping Arctic_hi_0013-02-14.png (file exists)
# Skipping Arctic_hi_0013-02-15.png (file exists)
# Skipping Arctic_hi_0013-02-16.png (file exists)
# Skipping Arctic_hi_0013-02-17.png (file exists)
# Skipping Arctic_hi_0013-02-18.png (file exists)
# Skipping Arctic_hi_0013-02-19.png (file exists)
# Skipping Arctic_hi_0013-02-20.png (file exists)
# Skipping Arctic_hi_0013-02-21.png (file exists)
# Skipping Arctic_hi_0013-02-22.png (file exists)
# Skipping Arctic_hi_0013-02-23.png (file exists)
# Skipping Arctic_hi_0013-02-24.png (file exists)
# Skipping Arctic_hi_0013-02-25.png (file exists)
# Skipping Arctic_hi_0013-02-26.png (file exists)
# Skipping Arctic_hi_0013-02-27.png (file exists)
# Skipping Arctic_hi_0013-02-28.png (file exists)
# Skipping Arctic_hi_0013-03-01.png (file exists)
# Skipping Arctic_hi_0013-03-02.png (file exists)
# Skipping Arctic_hi_0013-03-03.png (file exists)
# Skipping Arctic_hi_0013-03-04.png (file exists)
# Skipping Arctic_hi_0013-03-05.png (file exists)
# Skipping Arctic_hi_0013-03-06.png (file exists)
# Skipping Arctic_hi_0013-03-07.png (file exists)
# Skipping Arctic_hi_0013-03-08.png (file exists)
# Skipping Arctic_hi_0013-03-09.png (file exists)
# Skipping Arctic_hi_0013-03-10.png (file exists)
# Skipping Arctic_hi_0013-03-11.png (file exists)
# Skipping Arctic_hi_0013-03-12.png (file exists)
# Skipping Arctic_hi_0013-03-13.png (file exists)
# Skipping Arctic_hi_0013-03-14.png (file exists)
# Skipping Arctic_hi_0013-03-15.png (file exists)
# Skipping Arctic_hi_0013-03-16.png (file exists)
# Skipping Arctic_hi_0013-03-17.png (file exists)
# Skipping Arctic_hi_0013-03-18.png (file exists)
# Skipping Arctic_hi_0013-03-19.png (file exists)
# Skipping Arctic_hi_0013-03-20.png (file exists)
# Skipping Arctic_hi_0013-03-21.png (file exists)
# Skipping Arctic_hi_0013-03-22.png (file exists)
# Skipping Arctic_hi_0013-03-23.png (file exists)
# Skipping Arctic_hi_0013-03-24.png (file exists)
# Skipping Arctic_hi_0013-03-25.png (file exists)
# Skipping Arctic_hi_0013-03-26.png (file exists)
# Skipping Arctic_hi_0013-03-27.png (file exists)
# Skipping Arctic_hi_0013-03-28.png (file exists)
# Skipping Arctic_hi_0013-03-29.png (file exists)
# Skipping Arctic_hi_0013-03-30.png (file exists)
# Skipping Arctic_hi_0013-03-31.png (file exists)
# Skipping Arctic_hi_0013-04-01.png (file exists)
# Skipping Arctic_hi_0013-04-02.png (file exists)
# Skipping Arctic_hi_0013-04-03.png (file exists)
# Skipping Arctic_hi_0013-04-04.png (file exists)
# Skipping Arctic_hi_0013-04-05.png (file exists)
# Skipping Arctic_hi_0013-04-06.png (file exists)
# Skipping Arctic_hi_0013-04-07.png (file exists)
# Skipping Arctic_hi_0013-04-08.png (file exists)
# Skipping Arctic_hi_0013-04-09.png (file exists)
# Skipping Arctic_hi_0013-04-10.png (file exists)
# Skipping Arctic_hi_0013-04-11.png (file exists)
# Skipping Arctic_hi_0013-04-12.png (file exists)
# Skipping Arctic_hi_0013-04-13.png (file exists)
# Skipping Arctic_hi_0013-04-14.png (file exists)
# Skipping Arctic_hi_0013-04-15.png (file exists)
# Skipping Arctic_hi_0013-04-16.png (file exists)
# Skipping Arctic_hi_0013-04-17.png (file exists)
# Skipping Arctic_hi_0013-04-18.png (file exists)
# Skipping Arctic_hi_0013-04-19.png (file exists)
# Skipping Arctic_hi_0013-04-20.png (file exists)
# Skipping Arctic_hi_0013-04-21.png (file exists)
# Skipping Arctic_hi_0013-04-22.png (file exists)
# Skipping Arctic_hi_0013-04-23.png (file exists)
# Skipping Arctic_hi_0013-04-24.png (file exists)
# Skipping Arctic_hi_0013-04-25.png (file exists)
# Skipping Arctic_hi_0013-04-26.png (file exists)
# Skipping Arctic_hi_0013-04-27.png (file exists)
# Skipping Arctic_hi_0013-04-28.png (file exists)
# Skipping Arctic_hi_0013-04-29.png (file exists)
# Skipping Arctic_hi_0013-04-30.png (file exists)
# Skipping Arctic_hi_0013-05-01.png (file exists)
# Skipping Arctic_hi_0013-05-02.png (file exists)
# Skipping Arctic_hi_0013-05-03.png (file exists)
# Skipping Arctic_hi_0013-05-04.png (file exists)
# Skipping Arctic_hi_0013-05-05.png (file exists)
# Skipping Arctic_hi_0013-05-06.png (file exists)
# Skipping Arctic_hi_0013-05-07.png (file exists)
# Skipping Arctic_hi_0013-05-08.png (file exists)
# Skipping Arctic_hi_0013-05-09.png (file exists)
# Skipping Arctic_hi_0013-05-10.png (file exists)
# Skipping Arctic_hi_0013-05-11.png (file exists)
# Skipping Arctic_hi_0013-05-12.png (file exists)
# Skipping Arctic_hi_0013-05-13.png (file exists)
# Skipping Arctic_hi_0013-05-14.png (file exists)
# Skipping Arctic_hi_0013-05-15.png (file exists)
# Skipping Arctic_hi_0013-05-16.png (file exists)
# Skipping Arctic_hi_0013-05-17.png (file exists)
# Skipping Arctic_hi_0013-05-18.png (file exists)
# Skipping Arctic_hi_0013-05-19.png (file exists)
# Skipping Arctic_hi_0013-05-20.png (file exists)
# Skipping Arctic_hi_0013-05-21.png (file exists)
# Skipping Arctic_hi_0013-05-22.png (file exists)
# Skipping Arctic_hi_0013-05-23.png (file exists)
# Skipping Arctic_hi_0013-05-24.png (file exists)
# Skipping Arctic_hi_0013-05-25.png (file exists)
# Skipping Arctic_hi_0013-05-26.png (file exists)
# Skipping Arctic_hi_0013-05-27.png (file exists)
# Skipping Arctic_hi_0013-05-28.png (file exists)
# Skipping Arctic_hi_0013-05-29.png (file exists)
# Skipping Arctic_hi_0013-05-30.png (file exists)
# Skipping Arctic_hi_0013-05-31.png (file exists)
# Skipping Arctic_hi_0013-06-01.png (file exists)
# Skipping Arctic_hi_0013-06-02.png (file exists)
# Skipping Arctic_hi_0013-06-03.png (file exists)
# Skipping Arctic_hi_0013-06-04.png (file exists)
# Skipping Arctic_hi_0013-06-05.png (file exists)
# Skipping Arctic_hi_0013-06-06.png (file exists)
# Skipping Arctic_hi_0013-06-07.png (file exists)
# Skipping Arctic_hi_0013-06-08.png (file exists)
# Skipping Arctic_hi_0013-06-09.png (file exists)
# Skipping Arctic_hi_0013-06-10.png (file exists)
# Skipping Arctic_hi_0013-06-11.png (file exists)
# Skipping Arctic_hi_0013-06-12.png (file exists)
# Skipping Arctic_hi_0013-06-13.png (file exists)
# Skipping Arctic_hi_0013-06-14.png (file exists)
# Skipping Arctic_hi_0013-06-15.png (file exists)
# Skipping Arctic_hi_0013-06-16.png (file exists)
# Skipping Arctic_hi_0013-06-17.png (file exists)
# Skipping Arctic_hi_0013-06-18.png (file exists)
# Skipping Arctic_hi_0013-06-19.png (file exists)
# Skipping Arctic_hi_0013-06-20.png (file exists)
# Skipping Arctic_hi_0013-06-21.png (file exists)
# Skipping Arctic_hi_0013-06-22.png (file exists)
# Skipping Arctic_hi_0013-06-23.png (file exists)
# Skipping Arctic_hi_0013-06-24.png (file exists)
# Skipping Arctic_hi_0013-06-25.png (file exists)
# Skipping Arctic_hi_0013-06-26.png (file exists)
# Skipping Arctic_hi_0013-06-27.png (file exists)
# Skipping Arctic_hi_0013-06-28.png (file exists)
# Skipping Arctic_hi_0013-06-29.png (file exists)
# Skipping Arctic_hi_0013-06-30.png (file exists)
# Skipping Arctic_hi_0013-07-01.png (file exists)
# Skipping Arctic_hi_0013-07-02.png (file exists)
# Skipping Arctic_hi_0013-07-03.png (file exists)
# Skipping Arctic_hi_0013-07-04.png (file exists)
# Skipping Arctic_hi_0013-07-05.png (file exists)
# Skipping Arctic_hi_0013-07-06.png (file exists)
# Skipping Arctic_hi_0013-07-07.png (file exists)
# Skipping Arctic_hi_0013-07-08.png (file exists)
# Skipping Arctic_hi_0013-07-09.png (file exists)
# Skipping Arctic_hi_0013-07-10.png (file exists)
# Skipping Arctic_hi_0013-07-11.png (file exists)
# Skipping Arctic_hi_0013-07-12.png (file exists)
# Skipping Arctic_hi_0013-07-13.png (file exists)
# Skipping Arctic_hi_0013-07-14.png (file exists)
# Skipping Arctic_hi_0013-07-15.png (file exists)
# Skipping Arctic_hi_0013-07-16.png (file exists)
# Skipping Arctic_hi_0013-07-17.png (file exists)
# Skipping Arctic_hi_0013-07-18.png (file exists)
# Skipping Arctic_hi_0013-07-19.png (file exists)
# Skipping Arctic_hi_0013-07-20.png (file exists)
# Skipping Arctic_hi_0013-07-21.png (file exists)
# Skipping Arctic_hi_0013-07-22.png (file exists)
# Skipping Arctic_hi_0013-07-23.png (file exists)
# Skipping Arctic_hi_0013-07-24.png (file exists)
# Skipping Arctic_hi_0013-07-25.png (file exists)
# Skipping Arctic_hi_0013-07-26.png (file exists)
# Skipping Arctic_hi_0013-07-27.png (file exists)
# Skipping Arctic_hi_0013-07-28.png (file exists)
# Skipping Arctic_hi_0013-07-29.png (file exists)
# Skipping Arctic_hi_0013-07-30.png (file exists)
# Skipping Arctic_hi_0013-07-31.png (file exists)
# Skipping Arctic_hi_0013-08-01.png (file exists)
# Skipping Arctic_hi_0013-08-02.png (file exists)
# Skipping Arctic_hi_0013-08-03.png (file exists)
# Skipping Arctic_hi_0013-08-04.png (file exists)
# Skipping Arctic_hi_0013-08-05.png (file exists)
# Skipping Arctic_hi_0013-08-06.png (file exists)
# Skipping Arctic_hi_0013-08-07.png (file exists)
# Skipping Arctic_hi_0013-08-08.png (file exists)
# Skipping Arctic_hi_0013-08-09.png (file exists)
# Skipping Arctic_hi_0013-08-10.png (file exists)
# Skipping Arctic_hi_0013-08-11.png (file exists)
# Skipping Arctic_hi_0013-08-12.png (file exists)
# Skipping Arctic_hi_0013-08-13.png (file exists)
# Skipping Arctic_hi_0013-08-14.png (file exists)
# Skipping Arctic_hi_0013-08-15.png (file exists)
# Skipping Arctic_hi_0013-08-16.png (file exists)
# Skipping Arctic_hi_0013-08-17.png (file exists)
# Skipping Arctic_hi_0013-08-18.png (file exists)
# Skipping Arctic_hi_0013-08-19.png (file exists)
# Skipping Arctic_hi_0013-08-20.png (file exists)
# Skipping Arctic_hi_0013-08-21.png (file exists)
# Skipping Arctic_hi_0013-08-22.png (file exists)
# Skipping Arctic_hi_0013-08-23.png (file exists)
# Skipping Arctic_hi_0013-08-24.png (file exists)
# Skipping Arctic_hi_0013-08-25.png (file exists)
# Skipping Arctic_hi_0013-08-26.png (file exists)
# Skipping Arctic_hi_0013-08-27.png (file exists)
# Skipping Arctic_hi_0013-08-28.png (file exists)
# Skipping Arctic_hi_0013-08-29.png (file exists)
# Skipping Arctic_hi_0013-08-30.png (file exists)
# Skipping Arctic_hi_0013-08-31.png (file exists)
# Skipping Arctic_hi_0013-09-01.png (file exists)
# Skipping Arctic_hi_0013-09-02.png (file exists)
# Skipping Arctic_hi_0013-09-03.png (file exists)
# Skipping Arctic_hi_0013-09-04.png (file exists)
# Skipping Arctic_hi_0013-09-05.png (file exists)
# Skipping Arctic_hi_0013-09-06.png (file exists)
# Skipping Arctic_hi_0013-09-07.png (file exists)
# Skipping Arctic_hi_0013-09-08.png (file exists)
# Skipping Arctic_hi_0013-09-09.png (file exists)
# Skipping Arctic_hi_0013-09-10.png (file exists)
# Skipping Arctic_hi_0013-09-11.png (file exists)
# Skipping Arctic_hi_0013-09-12.png (file exists)
# Skipping Arctic_hi_0013-09-13.png (file exists)
# Skipping Arctic_hi_0013-09-14.png (file exists)
# Skipping Arctic_hi_0013-09-15.png (file exists)
# Skipping Arctic_hi_0013-09-16.png (file exists)
# Skipping Arctic_hi_0013-09-17.png (file exists)
# Skipping Arctic_hi_0013-09-18.png (file exists)
# Skipping Arctic_hi_0013-09-19.png (file exists)
# Skipping Arctic_hi_0013-09-20.png (file exists)
# Skipping Arctic_hi_0013-09-21.png (file exists)
# Skipping Arctic_hi_0013-09-22.png (file exists)
# Skipping Arctic_hi_0013-09-23.png (file exists)
# Skipping Arctic_hi_0013-09-24.png (file exists)
# Skipping Arctic_hi_0013-09-25.png (file exists)
# Skipping Arctic_hi_0013-09-26.png (file exists)
# Skipping Arctic_hi_0013-09-27.png (file exists)
# Skipping Arctic_hi_0013-09-28.png (file exists)
# Skipping Arctic_hi_0013-09-29.png (file exists)
# Skipping Arctic_hi_0013-09-30.png (file exists)
# Skipping Arctic_hi_0013-10-01.png (file exists)
# Skipping Arctic_hi_0013-10-02.png (file exists)
# Skipping Arctic_hi_0013-10-03.png (file exists)
# Skipping Arctic_hi_0013-10-04.png (file exists)
# Skipping Arctic_hi_0013-10-05.png (file exists)
# Skipping Arctic_hi_0013-10-06.png (file exists)
# Skipping Arctic_hi_0013-10-07.png (file exists)
# Skipping Arctic_hi_0013-10-08.png (file exists)
# Skipping Arctic_hi_0013-10-09.png (file exists)
# Skipping Arctic_hi_0013-10-10.png (file exists)
# Skipping Arctic_hi_0013-10-11.png (file exists)
# Skipping Arctic_hi_0013-10-12.png (file exists)
# Skipping Arctic_hi_0013-10-13.png (file exists)
# Skipping Arctic_hi_0013-10-14.png (file exists)
# Skipping Arctic_hi_0013-10-15.png (file exists)
# Skipping Arctic_hi_0013-10-16.png (file exists)
# Skipping Arctic_hi_0013-10-17.png (file exists)
# Skipping Arctic_hi_0013-10-18.png (file exists)
# Skipping Arctic_hi_0013-10-19.png (file exists)
# Skipping Arctic_hi_0013-10-20.png (file exists)
# Skipping Arctic_hi_0013-10-21.png (file exists)
# Skipping Arctic_hi_0013-10-22.png (file exists)
# Skipping Arctic_hi_0013-10-23.png (file exists)
# Skipping Arctic_hi_0013-10-24.png (file exists)
# Skipping Arctic_hi_0013-10-25.png (file exists)
# Skipping Arctic_hi_0013-10-26.png (file exists)
# Skipping Arctic_hi_0013-10-27.png (file exists)
# Skipping Arctic_hi_0013-10-28.png (file exists)
# Skipping Arctic_hi_0013-10-29.png (file exists)
# Skipping Arctic_hi_0013-10-30.png (file exists)
# Skipping Arctic_hi_0013-10-31.png (file exists)
# Skipping Arctic_hi_0013-11-01.png (file exists)
# Skipping Arctic_hi_0013-11-02.png (file exists)
# Skipping Arctic_hi_0013-11-03.png (file exists)
# Skipping Arctic_hi_0013-11-04.png (file exists)
# Skipping Arctic_hi_0013-11-05.png (file exists)
# Skipping Arctic_hi_0013-11-06.png (file exists)
# Skipping Arctic_hi_0013-11-07.png (file exists)
# Skipping Arctic_hi_0013-11-08.png (file exists)
# Skipping Arctic_hi_0013-11-09.png (file exists)
# Skipping Arctic_hi_0013-11-10.png (file exists)
# Skipping Arctic_hi_0013-11-11.png (file exists)
# Skipping Arctic_hi_0013-11-12.png (file exists)
# Skipping Arctic_hi_0013-11-13.png (file exists)
# Skipping Arctic_hi_0013-11-14.png (file exists)
# Skipping Arctic_hi_0013-11-15.png (file exists)
# Skipping Arctic_hi_0013-11-16.png (file exists)
# Skipping Arctic_hi_0013-11-17.png (file exists)
# Skipping Arctic_hi_0013-11-18.png (file exists)
# Skipping Arctic_hi_0013-11-19.png (file exists)
# Skipping Arctic_hi_0013-11-20.png (file exists)
# Skipping Arctic_hi_0013-11-21.png (file exists)
# Skipping Arctic_hi_0013-11-22.png (file exists)
# Skipping Arctic_hi_0013-11-23.png (file exists)
# Skipping Arctic_hi_0013-11-24.png (file exists)
# Skipping Arctic_hi_0013-11-25.png (file exists)
# Skipping Arctic_hi_0013-11-26.png (file exists)
# Skipping Arctic_hi_0013-11-27.png (file exists)
# Skipping Arctic_hi_0013-11-28.png (file exists)
# Skipping Arctic_hi_0013-11-29.png (file exists)
# Skipping Arctic_hi_0013-11-30.png (file exists)
# Skipping Arctic_hi_0013-12-01.png (file exists)
# Skipping Arctic_hi_0013-12-02.png (file exists)
# Skipping Arctic_hi_0013-12-03.png (file exists)
# Skipping Arctic_hi_0013-12-04.png (file exists)
# Skipping Arctic_hi_0013-12-05.png (file exists)
# Skipping Arctic_hi_0013-12-06.png (file exists)
# Skipping Arctic_hi_0013-12-07.png (file exists)
# Skipping Arctic_hi_0013-12-08.png (file exists)
# Skipping Arctic_hi_0013-12-09.png (file exists)
# Skipping Arctic_hi_0013-12-10.png (file exists)
# Skipping Arctic_hi_0013-12-11.png (file exists)
# Skipping Arctic_hi_0013-12-12.png (file exists)
# Skipping Arctic_hi_0013-12-13.png (file exists)
# Skipping Arctic_hi_0013-12-14.png (file exists)
# Skipping Arctic_hi_0013-12-15.png (file exists)
# Skipping Arctic_hi_0013-12-16.png (file exists)
# Skipping Arctic_hi_0013-12-17.png (file exists)
# Skipping Arctic_hi_0013-12-18.png (file exists)
# Skipping Arctic_hi_0013-12-19.png (file exists)
# Skipping Arctic_hi_0013-12-20.png (file exists)
# Skipping Arctic_hi_0013-12-21.png (file exists)
# Skipping Arctic_hi_0013-12-22.png (file exists)
# Skipping Arctic_hi_0013-12-23.png (file exists)
# Skipping Arctic_hi_0013-12-24.png (file exists)
# Skipping Arctic_hi_0013-12-25.png (file exists)
# Skipping Arctic_hi_0013-12-26.png (file exists)
# Skipping Arctic_hi_0013-12-27.png (file exists)
# Skipping Arctic_hi_0013-12-28.png (file exists)
# Skipping Arctic_hi_0013-12-29.png (file exists)
# Skipping Arctic_hi_0013-12-30.png (file exists)
# Skipping Arctic_hi_0013-12-31.png (file exists)
# HBox(children=(IntProgress(value=0, description='day', max=365), HTML(value='')))
# Skipping Antarctic_hi_0013-01-01.png (file exists)
# Skipping Antarctic_hi_0013-01-02.png (file exists)
# Skipping Antarctic_hi_0013-01-03.png (file exists)
# Skipping Antarctic_hi_0013-01-04.png (file exists)
# Skipping Antarctic_hi_0013-01-05.png (file exists)
# Skipping Antarctic_hi_0013-01-06.png (file exists)
# Skipping Antarctic_hi_0013-01-07.png (file exists)
# Skipping Antarctic_hi_0013-01-08.png (file exists)
# Skipping Antarctic_hi_0013-01-09.png (file exists)
# Skipping Antarctic_hi_0013-01-10.png (file exists)
# Skipping Antarctic_hi_0013-01-11.png (file exists)
# Skipping Antarctic_hi_0013-01-12.png (file exists)
# Skipping Antarctic_hi_0013-01-13.png (file exists)
# Skipping Antarctic_hi_0013-01-14.png (file exists)
# Skipping Antarctic_hi_0013-01-15.png (file exists)
# Skipping Antarctic_hi_0013-01-16.png (file exists)
# Skipping Antarctic_hi_0013-01-17.png (file exists)
# Skipping Antarctic_hi_0013-01-18.png (file exists)
# Skipping Antarctic_hi_0013-01-19.png (file exists)
# Skipping Antarctic_hi_0013-01-20.png (file exists)
# Skipping Antarctic_hi_0013-01-21.png (file exists)
# Skipping Antarctic_hi_0013-01-22.png (file exists)
# Skipping Antarctic_hi_0013-01-23.png (file exists)
# Skipping Antarctic_hi_0013-01-24.png (file exists)
# Skipping Antarctic_hi_0013-01-25.png (file exists)
# Skipping Antarctic_hi_0013-01-26.png (file exists)
# Skipping Antarctic_hi_0013-01-27.png (file exists)
# Skipping Antarctic_hi_0013-01-28.png (file exists)
# Skipping Antarctic_hi_0013-01-29.png (file exists)
# Skipping Antarctic_hi_0013-01-30.png (file exists)
# Skipping Antarctic_hi_0013-01-31.png (file exists)
# Skipping Antarctic_hi_0013-02-01.png (file exists)
# Skipping Antarctic_hi_0013-02-02.png (file exists)
# Skipping Antarctic_hi_0013-02-03.png (file exists)
# Skipping Antarctic_hi_0013-02-04.png (file exists)
# Skipping Antarctic_hi_0013-02-05.png (file exists)
# Skipping Antarctic_hi_0013-02-06.png (file exists)
# Skipping Antarctic_hi_0013-02-07.png (file exists)
# Skipping Antarctic_hi_0013-02-08.png (file exists)
# Skipping Antarctic_hi_0013-02-09.png (file exists)
# Skipping Antarctic_hi_0013-02-10.png (file exists)
# Skipping Antarctic_hi_0013-02-11.png (file exists)
# Skipping Antarctic_hi_0013-02-12.png (file exists)
# Skipping Antarctic_hi_0013-02-13.png (file exists)
# Skipping Antarctic_hi_0013-02-14.png (file exists)
# Skipping Antarctic_hi_0013-02-15.png (file exists)
# Skipping Antarctic_hi_0013-02-16.png (file exists)
# Skipping Antarctic_hi_0013-02-17.png (file exists)
# Skipping Antarctic_hi_0013-02-18.png (file exists)
# Skipping Antarctic_hi_0013-02-19.png (file exists)
# Skipping Antarctic_hi_0013-02-20.png (file exists)
# Skipping Antarctic_hi_0013-02-21.png (file exists)
# Skipping Antarctic_hi_0013-02-22.png (file exists)
# Skipping Antarctic_hi_0013-02-23.png (file exists)
# Skipping Antarctic_hi_0013-02-24.png (file exists)
# Skipping Antarctic_hi_0013-02-25.png (file exists)
# Skipping Antarctic_hi_0013-02-26.png (file exists)
# Skipping Antarctic_hi_0013-02-27.png (file exists)
# Skipping Antarctic_hi_0013-02-28.png (file exists)
# Skipping Antarctic_hi_0013-03-01.png (file exists)
# Skipping Antarctic_hi_0013-03-02.png (file exists)
# Skipping Antarctic_hi_0013-03-03.png (file exists)
# Skipping Antarctic_hi_0013-03-04.png (file exists)
# Skipping Antarctic_hi_0013-03-05.png (file exists)
# Skipping Antarctic_hi_0013-03-06.png (file exists)
# Skipping Antarctic_hi_0013-03-07.png (file exists)
# Skipping Antarctic_hi_0013-03-08.png (file exists)
# Skipping Antarctic_hi_0013-03-09.png (file exists)
# Skipping Antarctic_hi_0013-03-10.png (file exists)
# Skipping Antarctic_hi_0013-03-11.png (file exists)
# Skipping Antarctic_hi_0013-03-12.png (file exists)
# Skipping Antarctic_hi_0013-03-13.png (file exists)
# Skipping Antarctic_hi_0013-03-14.png (file exists)
# Skipping Antarctic_hi_0013-03-15.png (file exists)
# Skipping Antarctic_hi_0013-03-16.png (file exists)
# Skipping Antarctic_hi_0013-03-17.png (file exists)
# Skipping Antarctic_hi_0013-03-18.png (file exists)
# Skipping Antarctic_hi_0013-03-19.png (file exists)
# Skipping Antarctic_hi_0013-03-20.png (file exists)
# Skipping Antarctic_hi_0013-03-21.png (file exists)
# Skipping Antarctic_hi_0013-03-22.png (file exists)
# Skipping Antarctic_hi_0013-03-23.png (file exists)
# Skipping Antarctic_hi_0013-03-24.png (file exists)
# Skipping Antarctic_hi_0013-03-25.png (file exists)
# Skipping Antarctic_hi_0013-03-26.png (file exists)
# Skipping Antarctic_hi_0013-03-27.png (file exists)
# Skipping Antarctic_hi_0013-03-28.png (file exists)
# Skipping Antarctic_hi_0013-03-29.png (file exists)
# Skipping Antarctic_hi_0013-03-30.png (file exists)
# Skipping Antarctic_hi_0013-03-31.png (file exists)
# Skipping Antarctic_hi_0013-04-01.png (file exists)
# Skipping Antarctic_hi_0013-04-02.png (file exists)
# Skipping Antarctic_hi_0013-04-03.png (file exists)
# Skipping Antarctic_hi_0013-04-04.png (file exists)
# Skipping Antarctic_hi_0013-04-05.png (file exists)
# Skipping Antarctic_hi_0013-04-06.png (file exists)
# Skipping Antarctic_hi_0013-04-07.png (file exists)
# Skipping Antarctic_hi_0013-04-08.png (file exists)
# Skipping Antarctic_hi_0013-04-09.png (file exists)
# Skipping Antarctic_hi_0013-04-10.png (file exists)
# Skipping Antarctic_hi_0013-04-11.png (file exists)
# Skipping Antarctic_hi_0013-04-12.png (file exists)
# Skipping Antarctic_hi_0013-04-13.png (file exists)
# Skipping Antarctic_hi_0013-04-14.png (file exists)
# Skipping Antarctic_hi_0013-04-15.png (file exists)
# Skipping Antarctic_hi_0013-04-16.png (file exists)
# Skipping Antarctic_hi_0013-04-17.png (file exists)
# Skipping Antarctic_hi_0013-04-18.png (file exists)
# Skipping Antarctic_hi_0013-04-19.png (file exists)
# Skipping Antarctic_hi_0013-04-20.png (file exists)
# Skipping Antarctic_hi_0013-04-21.png (file exists)
# Skipping Antarctic_hi_0013-04-22.png (file exists)
# Skipping Antarctic_hi_0013-04-23.png (file exists)
# Skipping Antarctic_hi_0013-04-24.png (file exists)
# Skipping Antarctic_hi_0013-04-25.png (file exists)
# Skipping Antarctic_hi_0013-04-26.png (file exists)
# Skipping Antarctic_hi_0013-04-27.png (file exists)
# Skipping Antarctic_hi_0013-04-28.png (file exists)
# Skipping Antarctic_hi_0013-04-29.png (file exists)
# Skipping Antarctic_hi_0013-04-30.png (file exists)
# Skipping Antarctic_hi_0013-05-01.png (file exists)
# Skipping Antarctic_hi_0013-05-02.png (file exists)
# Skipping Antarctic_hi_0013-05-03.png (file exists)
# Skipping Antarctic_hi_0013-05-04.png (file exists)
# Skipping Antarctic_hi_0013-05-05.png (file exists)
# Skipping Antarctic_hi_0013-05-06.png (file exists)
# Skipping Antarctic_hi_0013-05-07.png (file exists)
# Skipping Antarctic_hi_0013-05-08.png (file exists)
# Skipping Antarctic_hi_0013-05-09.png (file exists)
# Skipping Antarctic_hi_0013-05-10.png (file exists)
# Skipping Antarctic_hi_0013-05-11.png (file exists)
# Skipping Antarctic_hi_0013-05-12.png (file exists)
# Skipping Antarctic_hi_0013-05-13.png (file exists)
# Skipping Antarctic_hi_0013-05-14.png (file exists)
# Skipping Antarctic_hi_0013-05-15.png (file exists)
# Skipping Antarctic_hi_0013-05-16.png (file exists)
# Skipping Antarctic_hi_0013-05-17.png (file exists)
# Skipping Antarctic_hi_0013-05-18.png (file exists)
# Skipping Antarctic_hi_0013-05-19.png (file exists)
# Skipping Antarctic_hi_0013-05-20.png (file exists)
# Skipping Antarctic_hi_0013-05-21.png (file exists)
# Skipping Antarctic_hi_0013-05-22.png (file exists)
# Skipping Antarctic_hi_0013-05-23.png (file exists)
# Skipping Antarctic_hi_0013-05-24.png (file exists)
# Skipping Antarctic_hi_0013-05-25.png (file exists)
# Skipping Antarctic_hi_0013-05-26.png (file exists)
# Skipping Antarctic_hi_0013-05-27.png (file exists)
# Skipping Antarctic_hi_0013-05-28.png (file exists)
# Skipping Antarctic_hi_0013-05-29.png (file exists)
# Skipping Antarctic_hi_0013-05-30.png (file exists)
# Skipping Antarctic_hi_0013-05-31.png (file exists)
# Skipping Antarctic_hi_0013-06-01.png (file exists)
# Skipping Antarctic_hi_0013-06-02.png (file exists)
# Skipping Antarctic_hi_0013-06-03.png (file exists)
# Skipping Antarctic_hi_0013-06-04.png (file exists)
# Skipping Antarctic_hi_0013-06-05.png (file exists)
# Skipping Antarctic_hi_0013-06-06.png (file exists)
# Skipping Antarctic_hi_0013-06-07.png (file exists)
# Skipping Antarctic_hi_0013-06-08.png (file exists)
# Skipping Antarctic_hi_0013-06-09.png (file exists)
# Skipping Antarctic_hi_0013-06-10.png (file exists)
# Skipping Antarctic_hi_0013-06-11.png (file exists)
# Skipping Antarctic_hi_0013-06-12.png (file exists)
# Skipping Antarctic_hi_0013-06-13.png (file exists)
# Skipping Antarctic_hi_0013-06-14.png (file exists)
# Skipping Antarctic_hi_0013-06-15.png (file exists)
# Skipping Antarctic_hi_0013-06-16.png (file exists)
# Skipping Antarctic_hi_0013-06-17.png (file exists)
# Skipping Antarctic_hi_0013-06-18.png (file exists)
# Skipping Antarctic_hi_0013-06-19.png (file exists)
# Skipping Antarctic_hi_0013-06-20.png (file exists)
# Skipping Antarctic_hi_0013-06-21.png (file exists)
# Skipping Antarctic_hi_0013-06-22.png (file exists)
# Skipping Antarctic_hi_0013-06-23.png (file exists)
# Skipping Antarctic_hi_0013-06-24.png (file exists)
# Skipping Antarctic_hi_0013-06-25.png (file exists)
# Skipping Antarctic_hi_0013-06-26.png (file exists)
# Skipping Antarctic_hi_0013-06-27.png (file exists)
# Skipping Antarctic_hi_0013-06-28.png (file exists)
# Skipping Antarctic_hi_0013-06-29.png (file exists)
# Skipping Antarctic_hi_0013-06-30.png (file exists)
# Skipping Antarctic_hi_0013-07-01.png (file exists)
# Skipping Antarctic_hi_0013-07-02.png (file exists)
# Skipping Antarctic_hi_0013-07-03.png (file exists)
# Skipping Antarctic_hi_0013-07-04.png (file exists)
# Skipping Antarctic_hi_0013-07-05.png (file exists)
# Skipping Antarctic_hi_0013-07-06.png (file exists)
# Skipping Antarctic_hi_0013-07-07.png (file exists)
# Skipping Antarctic_hi_0013-07-08.png (file exists)
# Skipping Antarctic_hi_0013-07-09.png (file exists)
# Skipping Antarctic_hi_0013-07-10.png (file exists)
# Skipping Antarctic_hi_0013-07-11.png (file exists)
# Skipping Antarctic_hi_0013-07-12.png (file exists)
# Skipping Antarctic_hi_0013-07-13.png (file exists)
# Skipping Antarctic_hi_0013-07-14.png (file exists)
# Skipping Antarctic_hi_0013-07-15.png (file exists)
# Skipping Antarctic_hi_0013-07-16.png (file exists)
# Skipping Antarctic_hi_0013-07-17.png (file exists)
# Skipping Antarctic_hi_0013-07-18.png (file exists)
# Skipping Antarctic_hi_0013-07-19.png (file exists)
# Skipping Antarctic_hi_0013-07-20.png (file exists)
# Skipping Antarctic_hi_0013-07-21.png (file exists)
# Skipping Antarctic_hi_0013-07-22.png (file exists)
# Skipping Antarctic_hi_0013-07-23.png (file exists)
# Skipping Antarctic_hi_0013-07-24.png (file exists)
# Skipping Antarctic_hi_0013-07-25.png (file exists)
# Skipping Antarctic_hi_0013-07-26.png (file exists)
# Skipping Antarctic_hi_0013-07-27.png (file exists)
# Skipping Antarctic_hi_0013-07-28.png (file exists)
# Skipping Antarctic_hi_0013-07-29.png (file exists)
# Skipping Antarctic_hi_0013-07-30.png (file exists)
# Skipping Antarctic_hi_0013-07-31.png (file exists)
# Skipping Antarctic_hi_0013-08-01.png (file exists)
# Skipping Antarctic_hi_0013-08-02.png (file exists)
# Skipping Antarctic_hi_0013-08-03.png (file exists)
# Skipping Antarctic_hi_0013-08-04.png (file exists)
# Skipping Antarctic_hi_0013-08-05.png (file exists)
# Skipping Antarctic_hi_0013-08-06.png (file exists)
# Skipping Antarctic_hi_0013-08-07.png (file exists)
# Skipping Antarctic_hi_0013-08-08.png (file exists)
# Skipping Antarctic_hi_0013-08-09.png (file exists)
# Skipping Antarctic_hi_0013-08-10.png (file exists)
# Skipping Antarctic_hi_0013-08-11.png (file exists)
# Skipping Antarctic_hi_0013-08-12.png (file exists)
# Skipping Antarctic_hi_0013-08-13.png (file exists)
# Skipping Antarctic_hi_0013-08-14.png (file exists)
# Skipping Antarctic_hi_0013-08-15.png (file exists)
# Skipping Antarctic_hi_0013-08-16.png (file exists)
# Skipping Antarctic_hi_0013-08-17.png (file exists)
# Skipping Antarctic_hi_0013-08-18.png (file exists)
# Skipping Antarctic_hi_0013-08-19.png (file exists)
# Skipping Antarctic_hi_0013-08-20.png (file exists)
# Skipping Antarctic_hi_0013-08-21.png (file exists)
# Skipping Antarctic_hi_0013-08-22.png (file exists)
# Skipping Antarctic_hi_0013-08-23.png (file exists)
# Skipping Antarctic_hi_0013-08-24.png (file exists)
# Skipping Antarctic_hi_0013-08-25.png (file exists)
# Skipping Antarctic_hi_0013-08-26.png (file exists)
# Skipping Antarctic_hi_0013-08-27.png (file exists)
# Skipping Antarctic_hi_0013-08-28.png (file exists)
# Skipping Antarctic_hi_0013-08-29.png (file exists)
# Skipping Antarctic_hi_0013-08-30.png (file exists)
# Skipping Antarctic_hi_0013-08-31.png (file exists)
# Skipping Antarctic_hi_0013-09-01.png (file exists)
# Skipping Antarctic_hi_0013-09-02.png (file exists)
# Skipping Antarctic_hi_0013-09-03.png (file exists)
# Skipping Antarctic_hi_0013-09-04.png (file exists)
# Skipping Antarctic_hi_0013-09-05.png (file exists)
# Skipping Antarctic_hi_0013-09-06.png (file exists)
# Skipping Antarctic_hi_0013-09-07.png (file exists)
# Skipping Antarctic_hi_0013-09-08.png (file exists)
# Skipping Antarctic_hi_0013-09-09.png (file exists)
# Skipping Antarctic_hi_0013-09-10.png (file exists)
# Skipping Antarctic_hi_0013-09-11.png (file exists)
# Skipping Antarctic_hi_0013-09-12.png (file exists)
# Skipping Antarctic_hi_0013-09-13.png (file exists)
# Skipping Antarctic_hi_0013-09-14.png (file exists)
# Skipping Antarctic_hi_0013-09-15.png (file exists)
# Skipping Antarctic_hi_0013-09-16.png (file exists)
# Skipping Antarctic_hi_0013-09-17.png (file exists)
# Skipping Antarctic_hi_0013-09-18.png (file exists)
# Skipping Antarctic_hi_0013-09-19.png (file exists)
# Skipping Antarctic_hi_0013-09-20.png (file exists)
# Skipping Antarctic_hi_0013-09-21.png (file exists)
# Skipping Antarctic_hi_0013-09-22.png (file exists)
# Skipping Antarctic_hi_0013-09-23.png (file exists)
# Skipping Antarctic_hi_0013-09-24.png (file exists)
# Skipping Antarctic_hi_0013-09-25.png (file exists)
# Skipping Antarctic_hi_0013-09-26.png (file exists)
# Skipping Antarctic_hi_0013-09-27.png (file exists)
# Skipping Antarctic_hi_0013-09-28.png (file exists)
# Skipping Antarctic_hi_0013-09-29.png (file exists)
# Skipping Antarctic_hi_0013-09-30.png (file exists)
# Skipping Antarctic_hi_0013-10-01.png (file exists)
# Skipping Antarctic_hi_0013-10-02.png (file exists)
# Skipping Antarctic_hi_0013-10-03.png (file exists)
# Skipping Antarctic_hi_0013-10-04.png (file exists)
# Skipping Antarctic_hi_0013-10-05.png (file exists)
# Skipping Antarctic_hi_0013-10-06.png (file exists)
# Skipping Antarctic_hi_0013-10-07.png (file exists)
# Skipping Antarctic_hi_0013-10-08.png (file exists)
# Skipping Antarctic_hi_0013-10-09.png (file exists)
# Skipping Antarctic_hi_0013-10-10.png (file exists)
# Skipping Antarctic_hi_0013-10-11.png (file exists)
# Skipping Antarctic_hi_0013-10-12.png (file exists)
# Skipping Antarctic_hi_0013-10-13.png (file exists)
# Skipping Antarctic_hi_0013-10-14.png (file exists)
# Skipping Antarctic_hi_0013-10-15.png (file exists)
# Skipping Antarctic_hi_0013-10-16.png (file exists)
# Skipping Antarctic_hi_0013-10-17.png (file exists)
# Skipping Antarctic_hi_0013-10-18.png (file exists)
# Skipping Antarctic_hi_0013-10-19.png (file exists)
# Skipping Antarctic_hi_0013-10-20.png (file exists)
# Skipping Antarctic_hi_0013-10-21.png (file exists)
# Skipping Antarctic_hi_0013-10-22.png (file exists)
# Skipping Antarctic_hi_0013-10-23.png (file exists)
# Skipping Antarctic_hi_0013-10-24.png (file exists)
# Skipping Antarctic_hi_0013-10-25.png (file exists)
# Skipping Antarctic_hi_0013-10-26.png (file exists)
# Skipping Antarctic_hi_0013-10-27.png (file exists)
# Skipping Antarctic_hi_0013-10-28.png (file exists)
# Skipping Antarctic_hi_0013-10-29.png (file exists)
# Skipping Antarctic_hi_0013-10-30.png (file exists)
# Skipping Antarctic_hi_0013-10-31.png (file exists)
# Skipping Antarctic_hi_0013-11-01.png (file exists)
# Skipping Antarctic_hi_0013-11-02.png (file exists)
# Skipping Antarctic_hi_0013-11-03.png (file exists)
# Skipping Antarctic_hi_0013-11-04.png (file exists)
# Skipping Antarctic_hi_0013-11-05.png (file exists)
# Skipping Antarctic_hi_0013-11-06.png (file exists)
# Skipping Antarctic_hi_0013-11-07.png (file exists)
# Skipping Antarctic_hi_0013-11-08.png (file exists)
# Skipping Antarctic_hi_0013-11-09.png (file exists)
# Skipping Antarctic_hi_0013-11-10.png (file exists)
# Skipping Antarctic_hi_0013-11-11.png (file exists)
# Skipping Antarctic_hi_0013-11-12.png (file exists)
# Skipping Antarctic_hi_0013-11-13.png (file exists)
# Skipping Antarctic_hi_0013-11-14.png (file exists)
# Skipping Antarctic_hi_0013-11-15.png (file exists)
# Skipping Antarctic_hi_0013-11-16.png (file exists)
# Skipping Antarctic_hi_0013-11-17.png (file exists)
# Skipping Antarctic_hi_0013-11-18.png (file exists)
# Skipping Antarctic_hi_0013-11-19.png (file exists)
# Skipping Antarctic_hi_0013-11-20.png (file exists)
# Skipping Antarctic_hi_0013-11-21.png (file exists)
# Skipping Antarctic_hi_0013-11-22.png (file exists)
# Skipping Antarctic_hi_0013-11-23.png (file exists)
# Skipping Antarctic_hi_0013-11-24.png (file exists)
# Skipping Antarctic_hi_0013-11-25.png (file exists)
# Skipping Antarctic_hi_0013-11-26.png (file exists)
# Skipping Antarctic_hi_0013-11-27.png (file exists)
# Skipping Antarctic_hi_0013-11-28.png (file exists)
# Skipping Antarctic_hi_0013-11-29.png (file exists)
# Skipping Antarctic_hi_0013-11-30.png (file exists)
# Skipping Antarctic_hi_0013-12-01.png (file exists)
# Skipping Antarctic_hi_0013-12-02.png (file exists)
# Skipping Antarctic_hi_0013-12-03.png (file exists)
# Skipping Antarctic_hi_0013-12-04.png (file exists)
# Skipping Antarctic_hi_0013-12-05.png (file exists)
# Skipping Antarctic_hi_0013-12-06.png (file exists)
# Skipping Antarctic_hi_0013-12-07.png (file exists)
# Skipping Antarctic_hi_0013-12-08.png (file exists)
# Skipping Antarctic_hi_0013-12-09.png (file exists)
# Skipping Antarctic_hi_0013-12-10.png (file exists)
# Skipping Antarctic_hi_0013-12-11.png (file exists)
# Skipping Antarctic_hi_0013-12-12.png (file exists)
# Skipping Antarctic_hi_0013-12-13.png (file exists)
# Skipping Antarctic_hi_0013-12-14.png (file exists)
# Skipping Antarctic_hi_0013-12-15.png (file exists)
# Skipping Antarctic_hi_0013-12-16.png (file exists)
# Skipping Antarctic_hi_0013-12-17.png (file exists)
# Skipping Antarctic_hi_0013-12-18.png (file exists)
# Skipping Antarctic_hi_0013-12-19.png (file exists)
# Skipping Antarctic_hi_0013-12-20.png (file exists)
# Skipping Antarctic_hi_0013-12-21.png (file exists)
# Skipping Antarctic_hi_0013-12-22.png (file exists)
# Skipping Antarctic_hi_0013-12-23.png (file exists)
# Skipping Antarctic_hi_0013-12-24.png (file exists)
# Skipping Antarctic_hi_0013-12-25.png (file exists)
# Skipping Antarctic_hi_0013-12-26.png (file exists)
# Skipping Antarctic_hi_0013-12-27.png (file exists)
# Skipping Antarctic_hi_0013-12-28.png (file exists)
# Skipping Antarctic_hi_0013-12-29.png (file exists)
# Skipping Antarctic_hi_0013-12-30.png (file exists)
# Skipping Antarctic_hi_0013-12-31.png (file exists)
